# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
companies = pd.read_csv("companies_rated.csv")

# %%
companies
# Out:
#       company_id                    region        country  exchange  \
# 0        4455588      Africa / Middle East        Bahrain       BAX
# 1         883038      Africa / Middle East          Egypt      CASE
# 2        2472872      Africa / Middle East          Egypt      CASE
# 3       46263794      Africa / Middle East          Egypt      CASE
# 4       32339123      Africa / Middle East          Egypt      CASE
# ...          ...                       ...            ...       ...
# 7818       93339  United States and Canada  United States  NasdaqGS
# 7819      379316  United States and Canada  United States  NasdaqGS
# 7820    13757558  United States and Canada  United States     OTCPK
# 7821      874816  United States and Canada  United States     OTCPK
# 7822      334518  United States and Canada  United States     OTCPK
#
#                                  industry  \
# 0                                   Banks
# 1                                   Banks
# ...

# %%
plt.figure(figsize=(16,8))
companies["industry"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
companies["industry"].nunique()
# Out:
# 69

# %%
environmental_data = pd.read_csv("environmental_data_history_all.csv")

# %%
environmental_data
# Out:
#                           data_group  fiscal_year  \
# 0         Trucost Environmental Data         2002
# 1         Trucost Environmental Data         2002
# 2         Trucost Environmental Data         2002
# 3         Trucost Environmental Data         2002
# 4         Trucost Environmental Data         2002
# ...                              ...          ...
# 11011093  Trucost Environmental Data         2020
# 11011094  Trucost Environmental Data         2020
# 11011095  Trucost Environmental Data         2020
# 11011096  Trucost Environmental Data         2020
# 11011097  Trucost Environmental Data         2020
#
#                                                 sector_name  company_id  \
# 0         Accounting, tax preparation, bookkeeping, and ...      276601
# 1         Accounting, tax preparation, bookkeeping, and ...      276601
# 2         Accounting, tax preparation, bookkeeping, and ...      276601
# ...

# %%
environmental_data["data_item_name"].unique()
# Out:
# array(['Absolute: Air Pollutants Direct & Indirect Cost',
#        'Absolute: Air Pollutants Direct Cost',
#        'Absolute: Air Pollutants Indirect Cost',
#        'Absolute: Cooling, Process, and Purchased',
#        'Absolute: Direct & Indirect Cost', 'Absolute: Direct Cost',
#        'Absolute: GHG Direct',
#        'Absolute: GHG Direct & First Tier Indirect',
#        'Absolute: GHG Direct & Indirect Cost',
#        'Absolute: GHG Direct Cost', 'Absolute: GHG First Tier Indirect',
#        'Absolute: GHG Indirect Cost',
#        'Absolute: Greenhouse Gases Scope 1',
#        'Absolute: Greenhouse Gases Scope 2',
#        'Absolute: Greenhouse Gases Scope 3 Upstream',
#        'Absolute: Indirect Cost', 'Absolute: LWP Direct & Indirect Cost',
#        'Absolute: LWP Direct Cost', 'Absolute: LWP Indirect Cost',
#        'Absolute: Natural Resources Direct & Indirect Cost',
#        'Absolute: Natural Resources Direct Cost',
#        'Absolute: Natural Resources Indirect Cost',
# ...

# %%
mask = (environmental_data["data_item_name"] == 'Absolute: Waste Mining Tailings Direct') & (environmental_data["company_id"] == 6577407)
environmental_data[mask]
# Out:
#                          data_group  fiscal_year    sector_name  company_id  \
# 589524   Trucost Environmental Data         2005  Copper Mining     6577407
# 1591099  Trucost Environmental Data         2008  Copper Mining     6577407
# 1941468  Trucost Environmental Data         2009  Copper Mining     6577407
# 2315869  Trucost Environmental Data         2010  Copper Mining     6577407
# 2699564  Trucost Environmental Data         2011  Copper Mining     6577407
# 3091758  Trucost Environmental Data         2012  Copper Mining     6577407
# 3498536  Trucost Environmental Data         2013  Copper Mining     6577407
# 3971594  Trucost Environmental Data         2014  Copper Mining     6577407
# 4470244  Trucost Environmental Data         2015  Copper Mining     6577407
# 5077044  Trucost Environmental Data         2016  Copper Mining     6577407
# 6215579  Trucost Environmental Data         2017  Copper Mining     6577407
# ...

# %%
plt.figure(figsize=(16,8))
environmental_data["data_item_name"].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>
